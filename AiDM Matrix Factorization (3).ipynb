# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt
import math
import sys

import datetime

# %%
#Users data
usersData = pd.read_csv('users.dat', sep='::', header=None, names=['UserID', 'Gender', 'Age', 'Occupation', 'Zip-code'], engine='python')

#Ratings data
ratingsData = pd.read_csv('ratings.dat', sep='::', header=None, names=['UserID', 'MovieID', 'Rating', 'Timestamp'], engine='python')
ratings_testData = pd.read_csv('ratings_test.dat', sep='::', header=None, names=['UserID', 'MovieID', 'Rating', 'Timestamp'], engine='python')

#Movies data
moviesData = pd.read_csv('movies.dat', sep='::', header=None, names=['MovieID', 'Title', 'Genres'], engine='python', encoding='latin1')

# %%
#Users data
print(usersData.head())

#Ratings data
print(ratingsData.head())
print(ratings_testData.head())

#Movies data
print(moviesData.head())
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
totalRMSE = 0
totalRMSE_function = 0

def rmse_func(test_matrix, pred_matrix):
    """
    Function that calculates the RMSE between the test and predicted matrices
    
    Arguments:
        test_matrix: The test matrix from 5-fold split
        pred_matrix: The prtedicted training matrix from 5-fold split
        
    """
    #initialize the errors of the previous and current step such that the condition is held for the first loop 
    rmse_old = float('inf')
    rmse_new = np.sqrt(np.nanmean(test_matrix-pred_matrix)**2)
    
    while rmse_new > 0.1 and (rmse_old - rmse_new > 1e-5):

        diff = test_matrix-pred_matrix
        rmse_old = rmse_new
        rmse_new = np.sqrt(np.nanmean(diff**2)) #compute the RMSE between the test and predicted matrices
    
    print("RMSE from the function:", rmse_new)    
    return rmse_new 

def matrix_factorization(X_train, X_test, K, num_iter, r, l):
    totalRMSE = 0
    """
    Function that performs matrix factorization to obtain the empty (NaN) points in the given matrix

    Arguments:
        X: Full User-Movie rating matrix 
        K: Number of latent features
        num_iter: Number of iterations
        r: Regularization parameter
        l: Learning rate
        

    Returns:
        U: User-feature matrix
        M: Feature-Movie matrix
            np.dot(U, M.T) will then give the predicted Rating Matrix 
        
    """
    
    #We will follow the steps given in chapter 3.1 of the gravity-Tikk.pdf paper:
    I, J = X_train.shape
    U = np.random.rand(I, K) #U is an I x K matrix with randomly distributed weights 
    M = np.random.rand(J, K) #M is an K x J matrix with randomly distributed weights 
     
    for iteration in range(num_iter):
        print("\nIteration: ", iteration)
        squared_error = 0
        num_ratings = 0
        
        """
        Because the test matrix and training matrix will not always be the same shape, we cannot subtract them from each
        other to calculate the RMSE in rmse_func on top. Typically the test matrix is smaller than the training matrix,
        so we will add rows and columns of NaN values to make their shapes equal. Since any NaN values are not used when
        calculating the RMSE, this does not change its value. 
        """
        
        X_test_orig = X_test
        
        rows_extra = X_train.shape[0]-X_test.shape[0] #extra rows needed to make shape of X_test same as X_train
        columns_extra = X_train.shape[1]-X_test.shape[1] #extra columns needed to make shape of X_test same as X_train

        nan_matrix_col = np.empty((X_test.shape[0], columns_extra)) #make empty matrix of right shape (extra columns)
        nan_matrix_col[:] = np.nan #fill empty matrix with NaNs
        X_test = np.column_stack((X_test, nan_matrix_col)) #add the extra columns to X_test
        nan_matrix_row = np.empty((rows_extra, X_test.shape[1])) #make empty matrix of right shape (extra rows)
        nan_matrix_row[:] = np.nan #fill empty matrix with NaNs
        X_test = np.row_stack((X_test, nan_matrix_row)) #add the extra rows to X_test
        
        print("Original shape of X_test:", X_test_orig.shape, ", while shape of X_train is:", 
              X_train.shape)
        print("After adding empty (NaN) columns and rows, the shape of X_test is now:", X_test.shape)
        
        for i in range(I):
            for j in range(J):
                if X_train[i, j] >0: #i.e. non-NaN
                    eij = X_train[i, j] - np.dot(U[i, :], M[j, :])
                    #eij denotes the training error on the (i, j)th example
                    squared_error += eij**2
                    num_ratings += 1
                    
                    for k in range(K):
                        #For all latent features, apply eq.6&7 in gravity-Tikk.pdf
                        U[i, k] = U[i, k] + l * (2 * eij * M[j, k] - r * U[i, k])
                        M[j, k] = M[j, k] + l * (2 * eij * U[i, k] - r * M[j, k])
                    

        rmse = np.sqrt(squared_error / num_ratings) #This is the RMSE as calculated from the training error eij
        
        if rmse < 0.001: #if rmse falls below a 0.001 threshold, the algorithm stops, indicating that it has 
                         #converged to a satisfactory solution.
            break 
            
            
        
        
        predicted_X_train = np.dot(U, M.T) #the predicted training matrix

        rmse_function = rmse_func(X_test, predicted_X_train) #rmse determined from the function on top
        print("RMSE from rmse_func from iteration ", iteration, ": ", rmse_function)   
        print("RMSE from the training error in the for-loop after iteration ", iteration, ": ", rmse)    
        
        print("Original training set X_train:\n", X_train) #Print the original training matrix 
        print("Predicted training set predicted_X_train:\n", predicted_X_train) #Print the predicted training matrix
        
    now = datetime.datetime.now()
    print ("Time at end of iteration: ", now.strftime("%Y-%m-%d %H:%M:%S")) #To check how long it takes to run  
   
    return U, M, rmse, rmse_function



"""
To switch between the ratings_testData and the 'complete' ratingsData, switch the '#' in the lines below and in 
the next for-loop.
"""
df_total = ratings_testData.pivot(index = "UserID", columns ="MovieID", values = "Rating") 
#df_total = ratingsData.pivot(index = "UserID", columns ="MovieID", values = "Rating") 
X_total = np.array(df_total.to_numpy()) #Make numpy array of the selected ratings data

count_kfold = 1
kf = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kf.split(ratings_testData):
#for train_index, test_index in kf.split(ratingsData):
    now = datetime.datetime.now() #To check how long it takes to run 
    print ("Time at start of fold number", count_kfold, " :", now.strftime("%Y-%m-%d %H:%M:%S"))   
    
    train_set = ratingsData.iloc[train_index]
    test_set = ratingsData.iloc[test_index]
    
    #First, convert data into a numpy array
    df_train = train_set.pivot(index = "UserID", columns ="MovieID", values = "Rating")
    df_test = test_set.pivot(index = "UserID", columns ="MovieID", values = "Rating")
    X_train = np.array(df_train.to_numpy())
    X_test = np.array(df_test.to_numpy())
    
    U, M, rmse, rmse_function= matrix_factorization(X_train, X_test, K=10, num_iter=10, r=0.05, l=0.005)
    
    predicted_X_train = np.dot(U, M.T)

    print("RMSE estimate (from rmse-func) of fold number ", count_kfold, ": ", rmse_function)
    print("RMSE estimate (the training error in the for-loop) of fold number ", count_kfold, ": ", rmse)
    
    totalRMSE += rmse
    totalRMSE_function += rmse_function
    #np.save("predicted_U_"+str(count_kfold), U)
    #np.save("predicted_M_"+str(count_kfold), M)
    count_kfold += 1
    

# Calculate the average RMSE over all folds
averageRMSE = totalRMSE / 5
averageRMSE_function = totalRMSE_function / 5

print("The Average RMSE is", averageRMSE)
print("The Average RMSE (from function) is", averageRMSE_function)
# Out:
# Time at start of fold number 1  : 2023-10-20 11:39:58
#
# Iteration:  0
# Original shape of X_test: (998, 2906) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.328206723066356
# RMSE from rmse_func from iteration  0 :  1.328206723066356
# RMSE from the training error in the for-loop after iteration  0 :  1.0751694672790995
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[5.41306494 4.21991563 4.49929691 ... 3.25670909 3.11784126 3.96363694]
#  [5.9017544  4.02864089 4.43467412 ... 3.18574516 3.10224204 4.16638062]
#  [5.41273355 4.33703483 4.04443202 ... 2.9967844  2.7475083  4.13588792]
#  ...
#  [5.6452486  3.7162858  4.35638817 ... 3.2867016  3.32231399 3.68313811]
#  [4.76522359 3.80082456 3.95943808 ... 2.47428298 2.48280558 3.61444179]
#  [5.11793153 3.95279206 4.12443326 ... 2.89411383 2.72946706 3.780791  ]]
#
# Iteration:  1
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3071281595145054
# RMSE from rmse_func from iteration  1 :  1.3071281595145054
# RMSE from the training error in the for-loop after iteration  1 :  0.9434611310399957
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.18504712 3.3645294  3.41403227 ... 3.19863238 3.19904807 3.78411309]
#  [4.21338556 2.96181726 3.11043744 ... 2.8687215  2.89535708 3.69493624]
#  [4.14077265 3.47357369 2.99517457 ... 2.91825417 2.79664207 3.9073222 ]
#  ...
#  [4.6120476  3.12963308 3.56791603 ... 3.42649688 3.58997203 3.7876192 ]
#  [3.94257531 3.21504787 3.24943018 ... 2.6292032  2.72438538 3.61186398]
#  [4.23002498 3.39560521 3.38665281 ... 3.04664207 3.02150795 3.90346637]]
#
# Iteration:  2
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3126008523299384
# RMSE from rmse_func from iteration  2 :  1.3126008523299384
# RMSE from the training error in the for-loop after iteration  2 :  0.9173391693514896
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.26391248 3.44368414 3.40480965 ... 3.34886261 3.44809378 3.8468619 ]
#  [4.11216584 2.98286308 3.04113272 ... 2.90937044 3.02161546 3.67750017]
#  [4.15233611 3.52348719 2.96703415 ... 3.04315791 3.0132753  3.92900509]
#  ...
#  [4.57402025 3.20481851 3.5442391  ... 3.51754406 3.77535047 3.80979243]
#  [3.97991975 3.24825267 3.24138658 ... 2.74529838 2.91155077 3.59108704]
#  [4.2373196  3.44775941 3.35653282 ... 3.13821124 3.22316435 3.93051749]]
#
# Iteration:  3
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3183968165166395
# RMSE from rmse_func from iteration  3 :  1.3183968165166395
# RMSE from the training error in the for-loop after iteration  3 :  0.9062844007624663
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.30112728 3.45076148 3.3985692  ... 3.44189468 3.61904033 3.86309476]
#  [4.06673204 2.98810315 3.03024659 ... 2.95415457 3.13559442 3.68336686]
#  [4.15966833 3.52511491 2.94904338 ... 3.12491851 3.1667385  3.92149353]
#  ...
#  [4.55784919 3.23630723 3.55104472 ... 3.5823979  3.91064361 3.82228454]
#  [4.01554066 3.2543543  3.25386958 ... 2.82160094 3.04656952 3.57161795]
#  [4.24848421 3.45532137 3.3516206  ... 3.20018017 3.37329484 3.944994  ]]
#
# Iteration:  4
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3234988725351298
# RMSE from rmse_func from iteration  4 :  1.3234988725351298
# RMSE from the training error in the for-loop after iteration  4 :  0.8985790977619714
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.32297145 3.43694933 3.38645782 ... 3.50388594 3.74297803 3.86430995]
#  [4.03882058 2.98665563 3.02795094 ... 2.98887863 3.22652142 3.69217632]
#  [4.16354447 3.51252217 2.92307646 ... 3.17717257 3.27468346 3.90021914]
#  ...
#  [4.55253405 3.25826087 3.5594656  ... 3.62802531 4.00947562 3.83172979]
#  [4.04683101 3.2581504  3.26220877 ... 2.86699919 3.1403837  3.55221724]
#  [4.25995312 3.45074908 3.34589835 ... 3.24105915 3.48618334 3.95593202]]
#
# Iteration:  5
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3279779371044522
# RMSE from rmse_func from iteration  5 :  1.3279779371044522
# RMSE from the training error in the for-loop after iteration  5 :  0.8921180541915813
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.33965236 3.41740367 3.37433691 ... 3.54724653 3.83643906 3.86083233]
#  [4.01867652 2.98225712 3.02809305 ... 3.0134936  3.29708157 3.70001007]
#  [4.16871515 3.4984278  2.89519826 ... 3.21123517 3.35211847 3.87427644]
#  ...
#  [4.55351425 3.27993004 3.5700313  ... 3.65988976 4.08214591 3.83985589]
#  [4.07544911 3.26574012 3.26779731 ... 2.88911734 3.20254559 3.531636  ]
#  [4.27083006 3.44183006 3.33928345 ... 3.26624832 3.57140317 3.96539193]]
#
# Iteration:  6
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3320179051832357
# RMSE from rmse_func from iteration  6 :  1.3320179051832357
# RMSE from the training error in the for-loop after iteration  6 :  0.8860513503733544
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.35440994 3.39587607 3.36358045 ... 3.57772649 3.90817199 3.85555476]
#  [4.00317662 2.97630101 3.02901309 ... 3.03010776 3.35151946 3.70636713]
#  [4.17634926 3.48617245 2.8677566  ... 3.233069   3.40791263 3.84691191]
#  ...
#  [4.55832335 3.30377453 3.58376598 ... 3.68191535 4.13615042 3.84742512]
#  [4.10298868 3.27789858 3.27185502 ... 2.89344268 3.24023202 3.50903077]
#  [4.28110782 3.43019982 3.33200289 ... 3.2796095  3.63580906 3.97427753]]
#
# Iteration:  7
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3357735474525996
# RMSE from rmse_func from iteration  7 :  1.3357735474525996
# RMSE from the training error in the for-loop after iteration  7 :  0.8799585147995642
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.36843253 3.37356575 3.35423651 ... 3.59862676 3.96356677 3.8493471 ]
#  [3.99107948 2.96963228 3.02992705 ... 3.04074345 3.39343018 3.71131191]
#  [4.18607008 3.47649084 2.84137532 ... 3.24601242 3.44756364 3.81915488]
#  ...
#  [4.56526176 3.33054911 3.60138019 ... 3.69692137 4.17695967 3.85487172]
#  [4.13021061 3.29391276 3.27499143 ... 2.88398739 3.25884389 3.48385014]
#  [4.29093591 3.41627408 3.32402191 ... 3.2839789  3.68433266 3.98308953]]
#
# Iteration:  8
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.339357642177511
# RMSE from rmse_func from iteration  8 :  1.339357642177511
# RMSE from the training error in the for-loop after iteration  8 :  0.8736263916327547
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.38220765 3.3511846  3.34615087 ... 3.61215085 4.00624618 3.84247198]
#  [3.98182665 2.96292814 3.030411   ... 3.0470392  3.42556019 3.71490908]
#  [4.19691511 3.4694376  2.81620797 ... 3.25215068 3.47473445 3.79128087]
#  ...
#  [4.57286348 3.36031933 3.62337802 ... 3.70696686 4.20862467 3.8624792 ]
#  [4.15687311 3.31222609 3.27757574 ... 2.86396334 3.26270182 3.45591698]
#  [4.30042797 3.40028582 3.31523908 ... 3.28149207 3.72053316 3.99208821]]
#
# Iteration:  9
# Original shape of X_test: (1000, 3334) , while shape of X_train is: (1000, 3334)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3334)
# RMSE from the function: 1.3428472671440257
# RMSE from rmse_func from iteration  9 :  1.3428472671440257
# RMSE from the training error in the for-loop after iteration  9 :  0.8669789903710075
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.39589954 3.32944458 3.33920469 ... 3.61989701 4.03875491 3.83496816]
#  [3.97514159 2.95676371 3.03025918 ... 3.05029373 3.44997076 3.71714101]
#  [4.20769622 3.46497255 2.79231769 ... 3.25291511 3.49200788 3.76332778]
#  ...
#  [4.57966559 3.39270943 3.6499837  ... 3.71356133 4.23417008 3.87044595]
#  [4.18175077 3.33062161 3.27983996 ... 2.83624663 3.25554477 3.42558409]
#  [4.30963588 3.38254802 3.30554083 ... 3.27380413 3.74700154 4.00135488]]
# Time at end of iteration:  2023-10-20 11:40:53
# RMSE estimate (from rmse-func) of fold number  1 :  1.3428472671440257
# RMSE estimate (the training error in the for-loop) of fold number  1 :  0.8669789903710075
# Time at start of fold number 2  : 2023-10-20 11:40:53
#
# Iteration:  0
# Original shape of X_test: (1000, 2850) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2265299807509802
# RMSE from rmse_func from iteration  0 :  1.2265299807509802
# RMSE from the training error in the for-loop after iteration  0 :  1.0714912279957105
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[5.69944949 4.2315078  3.94714202 ... 3.86120943 3.63734189 4.08659307]
#  [5.11529703 4.01203673 3.7872421  ... 3.80221049 3.34103749 4.06690104]
#  [5.48299759 4.16873954 3.99763558 ... 3.94945385 3.75378983 4.07591314]
#  ...
#  [5.43608507 4.27681141 3.76664603 ... 3.95589136 3.86036512 4.05723844]
#  [4.56494607 3.68027603 3.52741829 ... 3.24599505 3.12742401 3.54954472]
#  [4.93400653 3.91175554 3.69018906 ... 3.68543485 3.63640843 3.70096654]]
#
# Iteration:  1
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2175719701244754
# RMSE from rmse_func from iteration  1 :  1.2175719701244754
# RMSE from the training error in the for-loop after iteration  1 :  0.9411945984021315
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.14923396 2.99311134 3.09652746 ... 3.39638599 3.34412693 3.60865897]
#  [3.76117306 2.92653564 3.04589222 ... 3.43356613 3.12786414 3.66959132]
#  [4.07420584 3.03012552 3.22678823 ... 3.57882826 3.52734913 3.69149341]
#  ...
#  [4.56198665 3.57082092 3.4316712  ... 4.04411754 4.03844721 4.20395868]
#  [3.84855791 3.04768146 3.12864698 ... 3.36241797 3.2758702  3.64363294]
#  [4.27246145 3.3610549  3.35835536 ... 3.86713172 3.88292313 3.82886281]]
#
# Iteration:  2
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2251185254252053
# RMSE from rmse_func from iteration  2 :  1.2251185254252053
# RMSE from the training error in the for-loop after iteration  2 :  0.9162897436725426
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.15302261 3.05187368 3.12851562 ... 3.49471715 3.52263508 3.67186147]
#  [3.70204418 2.93956631 3.02144352 ... 3.46881867 3.23512055 3.63354908]
#  [4.07208051 3.09060256 3.25503917 ... 3.66900926 3.6983928  3.73865711]
#  ...
#  [4.499946   3.60658614 3.43578721 ... 4.10195118 4.16029683 4.22873871]
#  [3.85642807 3.09083235 3.08938642 ... 3.46180002 3.39508435 3.66264333]
#  [4.28243163 3.43140661 3.31613771 ... 3.96702533 4.03389179 3.81729836]]
#
# Iteration:  3
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2318284530839037
# RMSE from rmse_func from iteration  3 :  1.2318284530839037
# RMSE from the training error in the for-loop after iteration  3 :  0.9054501890137414
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.17207663 3.08429383 3.14899916 ... 3.56565467 3.65515064 3.71766631]
#  [3.68175902 2.94440773 3.01042821 ... 3.50553942 3.31822364 3.60583092]
#  [4.0885935  3.1283067  3.27757272 ... 3.73761014 3.82918234 3.77568468]
#  ...
#  [4.46314614 3.61755564 3.43237172 ... 4.14120366 4.24486812 4.23620282]
#  [3.86696782 3.10720433 3.06496668 ... 3.53305418 3.47595987 3.66723451]
#  [4.30432648 3.46868979 3.27216102 ... 4.03553675 4.13981681 3.7905601 ]]
#
# Iteration:  4
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2376383885383555
# RMSE from rmse_func from iteration  4 :  1.2376383885383555
# RMSE from the training error in the for-loop after iteration  4 :  0.8979232319178525
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.18605343 3.09878943 3.15657525 ... 3.6096342  3.74572086 3.74782259]
#  [3.6736446  2.94255935 3.00448734 ... 3.53523985 3.37554388 3.58000978]
#  [4.10018735 3.14835842 3.29021807 ... 3.78083731 3.91972396 3.80018622]
#  ...
#  [4.43730649 3.61800881 3.42624809 ... 4.16743052 4.30181467 4.23758388]
#  [3.8725036  3.10859369 3.04987954 ... 3.58229585 3.52349958 3.66326625]
#  [4.33064085 3.49226414 3.23058543 ... 4.08505664 4.21515472 3.76044888]]
#
# Iteration:  5
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2428006782412906
# RMSE from rmse_func from iteration  5 :  1.2428006782412906
# RMSE from the training error in the for-loop after iteration  5 :  0.8916279091924452
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.19736233 3.10750742 3.1599616  ... 3.63826736 3.80814885 3.77060294]
#  [3.67149499 2.93811548 3.00377007 ... 3.55906933 3.41173311 3.55451076]
#  [4.10800758 3.1610983  3.30039945 ... 3.80807064 3.98165805 3.81862739]
#  ...
#  [4.41848281 3.61482432 3.42087404 ... 4.18527187 4.33849159 4.235729  ]
#  [3.87320084 3.10193462 3.0429963  ... 3.61627091 3.54368039 3.65286324]
#  [4.35853063 3.51042226 3.193102   ... 4.12232617 4.26837067 3.72858183]]
#
# Iteration:  6
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.247534162928192
# RMSE from rmse_func from iteration  6 :  1.247534162928192
# RMSE from the training error in the for-loop after iteration  6 :  0.88573063093401
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.20694937 3.11475978 3.16222109 ... 3.65819717 3.85097817 3.78966517]
#  [3.67327344 2.93235397 3.00787747 ... 3.57882895 3.43093171 3.52893176]
#  [4.11332501 3.17032297 3.3111167  ... 3.82532115 4.02289707 3.83456977]
#  ...
#  [4.40521386 3.60975263 3.41658142 ... 4.19794622 4.36017639 4.23187324]
#  [3.87004191 3.08961535 3.04255646 ... 3.63989301 3.54127848 3.63741347]
#  [4.38654521 3.52567776 3.15901668 ... 4.15165334 4.30524592 3.69530074]]
#
# Iteration:  7
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2520060376843596
# RMSE from rmse_func from iteration  7 :  1.2520060376843596
# RMSE from the training error in the for-loop after iteration  7 :  0.8798212454243194
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.21485393 3.12212796 3.16439257 ... 3.67312734 3.87949158 3.80664881]
#  [3.67823972 2.92592391 3.01662502 ... 3.59582914 3.43625771 3.50335132]
#  [4.11679557 3.17749215 3.32365523 ... 3.83607746 4.04854311 3.84994952]
#  ...
#  [4.39699138 3.60334819 3.41311937 ... 4.20760259 4.37069441 4.22674323]
#  [3.86398518 3.07278006 3.04730179 ... 3.65635829 3.52000827 3.61803076]
#  [4.41383762 3.53896155 3.12751974 ... 4.17586464 4.32989265 3.66081229]]
#
# Iteration:  8
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.2563416811560864
# RMSE from rmse_func from iteration  8 :  1.2563416811560864
# RMSE from the training error in the for-loop after iteration  8 :  0.8736855086217612
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.2209118  3.13028937 3.1668995  ... 3.68526329 3.89720868 3.82247734]
#  [3.68611448 2.91944753 3.03014714 ... 3.61088065 3.43014629 3.4782572 ]
#  [4.11880973 3.18334669 3.33873907 ... 3.84243375 4.06208504 3.86601147]
#  ...
#  [4.39370525 3.59594742 3.41024399 ... 4.21567893 4.37296067 4.22091229]
#  [3.8558706  3.05230872 3.05652477 ... 3.66763122 3.48311246 3.59591613]
#  [4.43986935 3.55070575 3.09809178 ... 4.19682821 4.34533456 3.62541516]]
#
# Iteration:  9
# Original shape of X_test: (1000, 3343) , while shape of X_train is: (1000, 3343)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3343)
# RMSE from the function: 1.260630834288498
# RMSE from rmse_func from iteration  9 :  1.260630834288498
# RMSE from the training error in the for-loop after iteration  9 :  0.8672327809292729
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.22497435 3.13955767 3.16991805 ... 3.69596162 3.90662773 3.83779208]
#  [3.69664891 2.91361687 3.04869195 ... 3.62438961 3.4147081  3.45450992]
#  [4.11963    3.18844345 3.35683795 ... 3.84569415 4.06608903 3.88365527]
#  ...
#  [4.39532298 3.58789402 3.40776052 ... 4.22312791 4.36935863 4.21493446]
#  [3.84640529 3.0291511  3.06984313 ... 3.67491481 3.43392439 3.57260698]
#  [4.46429969 3.56116697 3.07047271 ... 4.21578069 4.35389688 3.58954479]]
# Time at end of iteration:  2023-10-20 11:41:44
# RMSE estimate (from rmse-func) of fold number  2 :  1.260630834288498
# RMSE estimate (the training error in the for-loop) of fold number  2 :  0.8672327809292729
# Time at start of fold number 3  : 2023-10-20 11:41:44
#
# Iteration:  0
# Original shape of X_test: (999, 2904) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.3035033528801867
# RMSE from rmse_func from iteration  0 :  1.3035033528801867
# RMSE from the training error in the for-loop after iteration  0 :  1.079164578977374
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[5.9888401  3.78552212 4.59298799 ... 4.20039889 4.28784279 4.38635525]
#  [5.51080725 3.88205887 4.16379618 ... 3.81470227 3.74300415 3.98036682]
#  [5.60735734 3.60074684 3.94253702 ... 3.495066   3.68037335 4.11390276]
#  ...
#  [5.13182685 3.98728475 4.49907754 ... 3.47724009 3.79772885 4.05627828]
#  [4.99750331 3.56499725 4.14025886 ... 3.4845399  3.80491531 3.89509241]
#  [4.85173587 3.51053639 3.85470119 ... 3.38731636 4.13814689 3.97693784]]
#
# Iteration:  1
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.2866806988677328
# RMSE from rmse_func from iteration  1 :  1.2866806988677328
# RMSE from the training error in the for-loop after iteration  1 :  0.9437431694364666
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.31018878 2.79209938 3.39360481 ... 3.75203939 3.85236775 3.8993979 ]
#  [3.98067622 2.91856641 3.11484052 ... 3.45737637 3.40063618 3.57044849]
#  [4.34782297 2.89258502 3.11590371 ... 3.38412662 3.56350644 3.93356396]
#  ...
#  [4.21359734 3.41341396 3.84074865 ... 3.63769964 3.95078686 4.16656371]
#  [4.09128163 3.07246643 3.4436745  ... 3.60076461 3.86849649 3.97301214]
#  [4.14627383 3.05850436 3.33401944 ... 3.58947262 4.31446503 4.14176561]]
#
# Iteration:  2
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.2913280711251816
# RMSE from rmse_func from iteration  2 :  1.2913280711251816
# RMSE from the training error in the for-loop after iteration  2 :  0.9182672636958387
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.34488669 2.90808744 3.39543965 ... 3.85282113 3.96007881 3.95591127]
#  [3.91281402 2.9373952  3.08275497 ... 3.49858628 3.45223103 3.5529225 ]
#  [4.34458183 3.00404605 3.14295144 ... 3.51473427 3.67690782 3.98469906]
#  ...
#  [4.2101255  3.44162084 3.78480385 ... 3.73955818 4.03790717 4.18471834]
#  [4.08718256 3.14758954 3.36693844 ... 3.69704967 3.92162602 3.9957935 ]
#  [4.21360022 3.11502002 3.30739287 ... 3.69118275 4.3847971  4.16809694]]
#
# Iteration:  3
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.2956691553008304
# RMSE from rmse_func from iteration  3 :  1.2956691553008304
# RMSE from the training error in the for-loop after iteration  3 :  0.9074130218552247
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.37023626 2.96791861 3.40744103 ... 3.91666853 4.02560094 3.98534343]
#  [3.88890003 2.94102203 3.09445753 ... 3.54157451 3.50598886 3.55348197]
#  [4.33094248 3.05898307 3.17599564 ... 3.59927742 3.74446867 4.00735487]
#  ...
#  [4.21316199 3.43311726 3.76047987 ... 3.81350078 4.09449134 4.19379452]
#  [4.08283585 3.18301232 3.33849731 ... 3.76690693 3.95510152 4.00668932]
#  [4.26112973 3.12445912 3.29390675 ... 3.76093605 4.42285647 4.17924521]]
#
# Iteration:  4
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.2993866552205326
# RMSE from rmse_func from iteration  4 :  1.2993866552205326
# RMSE from the training error in the for-loop after iteration  4 :  0.8998496579507171
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.38864538 3.00496709 3.41293315 ... 3.95446216 4.06199264 4.00050993]
#  [3.87910068 2.93841616 3.11057352 ... 3.5718249  3.5469534  3.55517627]
#  [4.31237711 3.09381571 3.20221311 ... 3.65411197 3.78278533 4.01792269]
#  ...
#  [4.22130496 3.41861097 3.74292299 ... 3.86890103 4.13095831 4.20103616]
#  [4.07605363 3.20764292 3.32652768 ... 3.81671107 3.97192163 4.01222967]
#  [4.29916246 3.12170506 3.27914085 ... 3.81273744 4.44333809 4.18859299]]
#
# Iteration:  5
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.3026774611323368
# RMSE from rmse_func from iteration  5 :  1.3026774611323368
# RMSE from the training error in the for-loop after iteration  5 :  0.8935006522525702
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.40479855 3.032172   3.41728714 ... 3.97758212 4.0814947  4.01022839]
#  [3.87608429 2.93361098 3.12796082 ... 3.59134645 3.5764433  3.55578308]
#  [4.29386802 3.12265267 3.22810954 ... 3.69244336 3.80476359 4.02582556]
#  ...
#  [4.23289756 3.40458773 3.73057971 ... 3.91184237 4.1536845  4.20724981]
#  [4.06633697 3.22918608 3.32573357 ... 3.85231293 3.97540553 4.0145552 ]
#  [4.33000671 3.11449609 3.26396546 ... 3.85322343 4.45270027 4.1981772 ]]
#
# Iteration:  6
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.305725742326277
# RMSE from rmse_func from iteration  6 :  1.305725742326277
# RMSE from the training error in the for-loop after iteration  6 :  0.8875177564526866
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.4200078  3.05355077 3.42234217 ... 3.99177439 4.090214   4.01810298]
#  [3.87739349 2.92819288 3.14631628 ... 3.60329056 3.59695844 3.5553351 ]
#  [4.27681807 3.15022901 3.25641483 ... 3.72089716 3.81685028 4.03467401]
#  ...
#  [4.24720605 3.39203548 3.72269467 ... 3.9460761  4.16659974 4.21238124]
#  [4.05387549 3.24976566 3.33375719 ... 3.87772337 3.96793532 4.01468148]
#  [4.3551867  3.10454956 3.24849548 ... 3.88646894 4.45470148 4.20844258]]
#
# Iteration:  7
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.308660441871326
# RMSE from rmse_func from iteration  7 :  1.308660441871326
# RMSE from the training error in the for-loop after iteration  7 :  0.8814785209891836
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.43451082 3.070579   3.42841661 ... 4.00003488 4.09138273 4.02582913]
#  [3.88185745 2.92317051 3.16594322 ... 3.60997702 3.61032753 3.55414782]
#  [4.26155642 3.17846756 3.28823619 ... 3.74289426 3.82246716 4.04587463]
#  ...
#  [4.26388249 3.38105438 3.71885538 ... 3.97381147 4.17219735 4.21633061]
#  [4.03919456 3.27005975 3.3496616  ... 3.89558991 3.95138471 4.01319316]
#  [4.3758666  3.09242666 3.23253445 ... 3.91505109 4.45164718 4.21944745]]
#
# Iteration:  8
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.3115676673835126
# RMSE from rmse_func from iteration  8 :  1.3115676673835126
# RMSE from the training error in the for-loop after iteration  8 :  0.8751723598877249
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.44827104 3.0839257  3.43528447 ... 4.00402762 4.08691243 4.03433626]
#  [3.88871943 2.91937211 3.18758978 ... 3.61291408 3.61780197 3.55254578]
#  [4.24828246 3.20831893 3.32403803 ... 3.76035161 3.82369544 4.05993852]
#  ...
#  [4.28262685 3.37166533 3.71900369 ... 3.9962519  4.17217145 4.21908908]
#  [4.0232525  3.29017163 3.3732399  ... 3.90779808 3.92764361 4.01055129]
#  [4.39286332 3.07851031 3.21586793 ... 3.94058695 4.44498812 4.23108085]]
#
# Iteration:  9
# Original shape of X_test: (1000, 3326) , while shape of X_train is: (1000, 3326)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3326)
# RMSE from the function: 1.3145021700205437
# RMSE from rmse_func from iteration  9 :  1.3145021700205437
# RMSE from the training error in the for-loop after iteration  9 :  0.8685339206891991
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.46119361 3.09397558 3.44240941 ... 4.00472273 4.07807501 4.04412435]
#  [3.89741141 2.9174761  3.21233644 ... 3.61304691 3.62035689 3.55082176]
#  [4.23727925 3.24027876 3.36373789 ... 3.77442014 3.82196652 4.07682684]
#  ...
#  [4.30302294 3.36388198 3.72329536 ... 4.01393622 4.16779258 4.22071682]
#  [4.0075503  3.30991916 3.40431206 ... 3.91591596 3.89888536 4.0072403 ]
#  [4.40669209 3.06324079 3.19834218 ... 3.96406864 4.43567642 4.24312842]]
# Time at end of iteration:  2023-10-20 11:42:36
# RMSE estimate (from rmse-func) of fold number  3 :  1.3145021700205437
# RMSE estimate (the training error in the for-loop) of fold number  3 :  0.8685339206891991
# Time at start of fold number 4  : 2023-10-20 11:42:36
#
# Iteration:  0
# Original shape of X_test: (999, 2870) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.2730931758254602
# RMSE from rmse_func from iteration  0 :  1.2730931758254602
# RMSE from the training error in the for-loop after iteration  0 :  1.0759645865311431
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[5.82916458 4.12663923 4.4473702  ... 2.77233886 2.86717115 3.8889977 ]
#  [5.72223477 4.66256772 4.35846789 ... 2.7195122  2.650704   4.25030405]
#  [5.25696984 4.24234037 3.72068187 ... 2.01868865 2.55742442 4.12799513]
#  ...
#  [5.42107132 4.20675276 4.21059099 ... 2.09199538 2.7723877  3.9684712 ]
#  [5.33092972 3.96206506 3.97674857 ... 2.3212757  2.52011437 3.63080853]
#  [5.39481521 4.12256297 4.17910593 ... 2.47338334 2.49514663 3.91801353]]
#
# Iteration:  1
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.2570791682550135
# RMSE from rmse_func from iteration  1 :  1.2570791682550135
# RMSE from the training error in the for-loop after iteration  1 :  0.9443868706253634
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.35112598 2.96941041 3.61288047 ... 2.85303573 3.11161794 3.60483581]
#  [3.84244643 3.09248333 3.11925607 ... 2.50606785 2.57343973 3.55316619]
#  [3.88721541 3.07664107 2.88403179 ... 2.07916867 2.74259807 3.83635127]
#  ...
#  [4.41685858 3.33536016 3.71898843 ... 2.42778141 3.28222075 4.03529123]
#  [4.27428034 3.18659758 3.44007444 ... 2.60949844 2.9497118  3.71154281]
#  [4.4949869  3.40052399 3.72942668 ... 2.80070309 3.02777062 4.07050923]]
#
# Iteration:  2
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.262618919795078
# RMSE from rmse_func from iteration  2 :  1.262618919795078
# RMSE from the training error in the for-loop after iteration  2 :  0.918546500990998
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.32846449 3.06112722 3.63824082 ... 3.09090745 3.45881195 3.63247397]
#  [3.75030101 3.05277189 3.04325042 ... 2.64693796 2.81421863 3.50225185]
#  [3.92130788 3.14303742 2.90221664 ... 2.31658043 3.0629789  3.90041742]
#  ...
#  [4.37973124 3.35691631 3.71264791 ... 2.67984188 3.61647063 4.01678824]
#  [4.22345658 3.27459765 3.41685913 ... 2.85375245 3.26402527 3.76186518]
#  [4.46714552 3.46620985 3.69771199 ... 3.02469489 3.36250308 4.09063092]]
#
# Iteration:  3
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.2682483528793567
# RMSE from rmse_func from iteration  3 :  1.2682483528793567
# RMSE from the training error in the for-loop after iteration  3 :  0.907333716224756
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.3265753  3.10529398 3.6750714  ... 3.27534775 3.7016162  3.64538145]
#  [3.72852514 3.02871632 3.02433419 ... 2.77737106 3.00066876 3.49005536]
#  [3.94540357 3.16387295 2.92095442 ... 2.49967487 3.28124086 3.94288154]
#  ...
#  [4.358826   3.34558794 3.72474456 ... 2.87931096 3.84463857 3.98972552]
#  [4.21189963 3.32225479 3.41714489 ... 3.04967803 3.48651765 3.80352409]
#  [4.46417841 3.49111429 3.68188682 ... 3.19915757 3.59230587 4.09966477]]
#
# Iteration:  4
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.2734313410005742
# RMSE from rmse_func from iteration  4 :  1.2734313410005742
# RMSE from the training error in the for-loop after iteration  4 :  0.8994794245967385
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.32635173 3.12983682 3.70776024 ... 3.41577442 3.86900578 3.64872991]
#  [3.72488482 3.01211571 3.01632992 ... 2.88381684 3.13563723 3.485041  ]
#  [3.95073114 3.16499064 2.92809866 ... 2.63792194 3.4240994  3.9703291 ]
#  ...
#  [4.34077495 3.32983156 3.73986824 ... 3.03942696 4.00225679 3.96027514]
#  [4.21251218 3.35509234 3.42083508 ... 3.20629315 3.64192461 3.84012926]
#  [4.47097942 3.50625897 3.66952871 ... 3.3374975  3.7523387  4.10708547]]
#
# Iteration:  5
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.278215780277485
# RMSE from rmse_func from iteration  5 :  1.278215780277485
# RMSE from the training error in the for-loop after iteration  5 :  0.8928282620111728
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.32819538 3.14682153 3.74047073 ... 3.52407877 3.98572166 3.64816749]
#  [3.7288679  3.00234025 3.01332771 ... 2.96917129 3.23239011 3.481582  ]
#  [3.94344731 3.15873467 2.92966994 ... 2.744003   3.51560579 3.99065797]
#  ...
#  [4.32372054 3.31682235 3.75818121 ... 3.17044934 4.11288231 3.92951223]
#  [4.21875516 3.38102024 3.42642167 ... 3.33246511 3.74857801 3.87377568]
#  [4.48346131 3.51999763 3.66099141 ... 3.44912024 3.86497091 4.11464276]]
#
# Iteration:  6
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.282718603761014
# RMSE from rmse_func from iteration  6 :  1.282718603761014
# RMSE from the training error in the for-loop after iteration  6 :  0.886507858347351
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.33254067 3.16012402 3.77512152 ... 3.60883372 4.06803521 3.64622224]
#  [3.7371339  2.99824382 3.01392543 ... 3.03813858 3.30175712 3.4785561 ]
#  [3.92686058 3.14892452 2.92815937 ... 2.82681038 3.57117509 4.00734082]
#  ...
#  [4.30741297 3.30752556 3.77968059 ... 3.28016539 4.19212533 3.89777734]
#  [4.22867531 3.40170312 3.4330038  ... 3.43496097 3.81908169 3.90574891]
#  [4.50003068 3.53436597 3.65629004 ... 3.54118386 3.94518926 4.12306024]]
#
# Iteration:  7
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.2870501937348682
# RMSE from rmse_func from iteration  7 :  1.2870501937348682
# RMSE from the training error in the for-loop after iteration  7 :  0.8800888212513353
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.33929599 3.17123988 3.81240944 ... 3.67610453 4.12657496 3.64403511]
#  [3.74830502 2.99886769 3.01779671 ... 3.09495387 3.35148989 3.47592312]
#  [3.90266399 3.13684884 2.92445806 ... 2.89261517 3.60064418 4.02189348]
#  ...
#  [4.29202079 3.30168162 3.80428112 ... 3.37436523 4.25036733 3.86535817]
#  [4.24177963 3.41706502 3.43974048 ... 3.51840951 3.8620931  3.93657784]
#  [4.51972593 3.55000506 3.6552349  ... 3.61901166 4.00312068 4.13269889]]
#
# Iteration:  8
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.2912980288953715
# RMSE from rmse_func from iteration  8 :  1.2912980288953715
# RMSE from the training error in the for-loop after iteration  8 :  0.8733624491133872
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.34819273 3.1809274  3.85256894 ... 3.73024162 4.1684616  3.64220928]
#  [3.76187273 3.00344114 3.02503944 ... 3.1430227  3.3870259  3.47396761]
#  [3.87215943 3.12301847 2.91902911 ... 2.94598853 3.61049075 4.03507822]
#  ...
#  [4.27805773 3.29879056 3.83196697 ... 3.45723242 4.2945884  3.83267561]
#  [4.25797577 3.42659655 3.4459208  ... 3.58570026 3.88388613 3.96617777]
#  [4.54167489 3.56719585 3.65754927 ... 3.68645733 4.04567668 4.1436806 ]]
#
# Iteration:  9
# Original shape of X_test: (1000, 3339) , while shape of X_train is: (1000, 3339)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3339)
# RMSE from the function: 1.295521014034701
# RMSE from rmse_func from iteration  9 :  1.295521014034701
# RMSE from the training error in the for-loop after iteration  9 :  0.8662724345353112
# Original training set X_train:
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.35890446 3.18967089 3.89557602 ... 3.77436208 4.19859723 3.64109747]
#  [3.77782263 3.01125715 3.0359069  ... 3.1848991  3.41221324 3.47302763]
#  [3.83686632 3.10766573 2.91234874 ... 2.99030737 3.60517622 4.04736701]
#  ...
#  [4.26636058 3.29828052 3.86274273 ... 3.53162557 4.3295543  3.80028643]
#  [4.27693176 3.43003701 3.45102421 ... 3.63859206 3.8894645  3.99407982]
#  [4.56487518 3.5860936  3.66282223 ... 3.74622051 4.07762164 4.1559241 ]]
# Time at end of iteration:  2023-10-20 11:43:27
# RMSE estimate (from rmse-func) of fold number  4 :  1.295521014034701
# RMSE estimate (the training error in the for-loop) of fold number  4 :  0.8662724345353112
# Time at start of fold number 5  : 2023-10-20 11:43:27
#
# Iteration:  0
# Original shape of X_test: (1000, 2864) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2271487757906525
# RMSE from rmse_func from iteration  0 :  1.2271487757906525
# RMSE from the training error in the for-loop after iteration  0 :  1.0729050469298207
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[5.36711727 4.33336773 4.53538665 ... 4.72654639 3.99142597 4.17363097]
#  [5.12384404 4.15747598 4.45621895 ... 4.70016808 4.00894749 4.10012189]
#  [5.10512308 3.91679847 4.2618498  ... 4.5165069  3.61007725 4.67097893]
#  ...
#  [5.301623   4.16024533 3.93058325 ... 4.47231358 4.11212375 3.50248369]
#  [4.79392401 3.77680914 3.6031317  ... 3.86461398 3.43033393 3.73227479]
#  [4.88150182 3.7524131  4.18018215 ... 3.88712645 3.15697438 4.47933333]]
#
# Iteration:  1
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2215675865477507
# RMSE from rmse_func from iteration  1 :  1.2215675865477507
# RMSE from the training error in the for-loop after iteration  1 :  0.9403085246831104
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.14096897 3.30037473 3.5076512  ... 4.25509736 3.76222082 3.78193355]
#  [3.65559397 3.00953094 3.26724248 ... 3.99973749 3.52599471 3.49171688]
#  [4.09313881 3.07617704 3.40141971 ... 4.19322323 3.52883576 4.39810709]
#  ...
#  [4.55401649 3.54921138 3.40045526 ... 4.46668472 4.26877215 3.63941708]
#  [4.1009296  3.16623629 3.08698139 ... 3.81872656 3.58099576 3.71928602]
#  [4.24113124 3.26552825 3.65885992 ... 3.95747878 3.41667264 4.52693414]]
#
# Iteration:  2
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.231462257587318
# RMSE from rmse_func from iteration  2 :  1.231462257587318
# RMSE from the training error in the for-loop after iteration  2 :  0.9151403597289849
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.18064557 3.3264707  3.472889   ... 4.31167782 3.90877977 3.82671102]
#  [3.59574983 2.99774901 3.16748117 ... 3.96035315 3.55001341 3.44540338]
#  [4.11096432 3.11425887 3.34822029 ... 4.22286615 3.66790581 4.39906506]
#  ...
#  [4.5206487  3.56832515 3.40573525 ... 4.47152926 4.3466567  3.70017726]
#  [4.06861935 3.160479   3.0817285  ... 3.81229406 3.67835715 3.70719522]
#  [4.21255765 3.31198632 3.60554992 ... 3.99297809 3.55342561 4.49955033]]
#
# Iteration:  3
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2396173494976779
# RMSE from rmse_func from iteration  3 :  1.2396173494976779
# RMSE from the training error in the for-loop after iteration  3 :  0.9043804573863384
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.21386995 3.32231002 3.45012487 ... 4.36113657 4.00161443 3.84947442]
#  [3.58766293 2.99417638 3.12143875 ... 3.96898029 3.57665855 3.43069038]
#  [4.12857    3.12771618 3.30994793 ... 4.24967328 3.75586074 4.38939559]
#  ...
#  [4.50747829 3.56306186 3.42840551 ... 4.48815967 4.38830674 3.74343934]
#  [4.05812993 3.15115643 3.1013837  ... 3.81885101 3.73627836 3.70535252]
#  [4.20141718 3.33120211 3.57290118 ... 4.02892211 3.63892538 4.47088915]]
#
# Iteration:  4
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.246328668691144
# RMSE from rmse_func from iteration  4 :  1.246328668691144
# RMSE from the training error in the for-loop after iteration  4 :  0.8970048577704444
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.2332689  3.30504629 3.42477191 ... 4.39993158 4.05819134 3.85740621]
#  [3.59061557 2.9924973  3.09087369 ... 3.99146843 3.59435538 3.42492872]
#  [4.13548298 3.13197207 3.27104312 ... 4.26751148 3.80784829 4.37205039]
#  ...
#  [4.49925342 3.55020214 3.4514234  ... 4.50966838 4.40964123 3.7773313 ]
#  [4.05483663 3.14268975 3.12622222 ... 3.83063763 3.76820176 3.7114963 ]
#  [4.19726799 3.34342638 3.54646891 ... 4.0642433  3.69472336 4.44691246]]
#
# Iteration:  5
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2520513644286824
# RMSE from rmse_func from iteration  5 :  1.2520513644286824
# RMSE from the training error in the for-loop after iteration  5 :  0.8909216664928332
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.24541796 3.28447951 3.40068965 ... 4.43287866 4.09466725 3.8583155 ]
#  [3.59657062 2.9923181  3.06902556 ... 4.0191558  3.60549589 3.4225391 ]
#  [4.13601346 3.13575496 3.234437   ... 4.27973898 3.83876211 4.35208015]
#  ...
#  [4.49341176 3.53458309 3.47400238 ... 4.53352617 4.42039075 3.80471825]
#  [4.05626161 3.13448781 3.15371681 ... 3.84529163 3.78343161 3.72373538]
#  [4.19751452 3.35460331 3.52476393 ... 4.09813115 3.73251171 4.42773205]]
#
# Iteration:  6
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.257114233590096
# RMSE from rmse_func from iteration  6 :  1.257114233590096
# RMSE from the training error in the for-loop after iteration  6 :  0.8853115989621456
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.25352586 3.2633911  3.37898702 ... 4.46211849 4.11957322 3.85542098]
#  [3.60290364 2.99260529 3.0528522  ... 4.04894153 3.61274161 3.42121982]
#  [4.1326965  3.141975   3.20128629 ... 4.28847668 3.85718599 4.33159293]
#  ...
#  [4.48899953 3.51687404 3.49572506 ... 4.55876863 4.42622519 3.82705242]
#  [4.06145258 3.12453173 3.18238899 ... 3.86203903 3.78772659 3.74085171]
#  [4.20074285 3.36608341 3.50656098 ... 4.13044636 3.75907622 4.41276176]]
#
# Iteration:  7
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2617445656099495
# RMSE from rmse_func from iteration  7 :  1.2617445656099495
# RMSE from the training error in the for-loop after iteration  7 :  0.8797737199267075
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.25912202 3.24250907 3.35980812 ... 4.48864269 4.13746687 3.85016508]
#  [3.6085566  2.99243844 3.04053829 ... 4.07957626 3.61789208 3.41976385]
#  [4.12678315 3.15171211 3.17191253 ... 4.29492127 3.86794097 4.31132872]
#  ...
#  [4.48541624 3.49698309 3.51633359 ... 4.58503087 4.430391   3.84526357]
#  [4.06964735 3.11113483 3.21095839 ... 3.88047539 3.78445725 3.76201868]
#  [4.20605556 3.37816441 3.49090938 ... 4.16133377 3.77844023 4.40144122]]
#
# Iteration:  8
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2661031566916336
# RMSE from rmse_func from iteration  8 :  1.2661031566916336
# RMSE from the training error in the for-loop after iteration  8 :  0.8740895819702341
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.2630735  3.22198942 3.3431521  ... 4.51303684 4.15090909 3.84337677]
#  [3.6130797  2.9911119  3.03083941 ... 4.11054675 3.6220624  3.41747807]
#  [4.11899633 3.16545606 3.14647896 ... 4.29983456 3.87384116 4.29154029]
#  ...
#  [4.48220426 3.47481242 3.53573576 ... 4.61216319 4.43473619 3.86007617]
#  [4.08002764 3.09314628 3.23818998 ... 3.90009712 3.77549415 3.78666043]
#  [4.21290611 3.39084554 3.47713469 ... 4.19099927 3.79303137 4.39334713]]
#
# Iteration:  9
# Original shape of X_test: (1000, 3332) , while shape of X_train is: (1000, 3332)
# After adding empty (NaN) columns and rows, the shape of X_test is now: (1000, 3332)
# RMSE from the function: 1.2703058814069554
# RMSE from rmse_func from iteration  9 :  1.2703058814069554
# RMSE from the training error in the for-loop after iteration  9 :  0.8681445516403641
# Original training set X_train:
#  [[ 5. nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [ 5. nan nan ... nan nan nan]]
# Predicted training set predicted_X_train:
#  [[4.26593202 3.20183501 3.32906043 ... 4.53570449 4.16139196 3.83566264]
#  [3.61624973 2.98814387 3.02278241 ... 4.14161919 3.62591086 3.41397621]
#  [4.10985844 3.18344887 3.12518977 ... 4.30373938 3.87660802 4.27234205]
#  ...
#  [4.47897407 3.45045011 3.55396812 ... 4.64005009 4.44029818 3.8721543 ]
#  [4.09170178 3.06999099 3.26293364 ... 3.92011713 3.76182035 3.81441902]
#  [4.22098342 3.40398744 3.46477227 ... 4.21958696 3.80432856 4.38818606]]
# Time at end of iteration:  2023-10-20 11:44:20
# RMSE estimate (from rmse-func) of fold number  5 :  1.2703058814069554
# RMSE estimate (the training error in the for-loop) of fold number  5 :  0.8681445516403641
# The Average RMSE is 0.867432535633031
# The Average RMSE (from function) is 1.2967614333789448
